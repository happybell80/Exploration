# %%
import pandas as pd
import os

fname = os.getenv('HOME') + '/aiffel/recommendata_iu/data/lastfm-dataset-360K/usersha1-artmbid-artname-plays.tsv'
col_names = ['user_id', 'artist_MBID', 'artist', 'play']   # 임의로 지정한 컬럼명
data = pd.read_csv(fname, sep='\t', names= col_names)      # sep='\t'로 주어야 tsv를 열 수 있습니다.  
data.head(10)
# Out:
#                                     user_id  \
# 0  00000c289a1829a808ac09c00daf10bc3c4e223b
# 1  00000c289a1829a808ac09c00daf10bc3c4e223b
# 2  00000c289a1829a808ac09c00daf10bc3c4e223b
# 3  00000c289a1829a808ac09c00daf10bc3c4e223b
# 4  00000c289a1829a808ac09c00daf10bc3c4e223b
# 5  00000c289a1829a808ac09c00daf10bc3c4e223b
# 6  00000c289a1829a808ac09c00daf10bc3c4e223b
# 7  00000c289a1829a808ac09c00daf10bc3c4e223b
# 8  00000c289a1829a808ac09c00daf10bc3c4e223b
# 9  00000c289a1829a808ac09c00daf10bc3c4e223b
#
#                             artist_MBID                   artist  play
# 0  3bd73256-3905-4f3a-97e2-8b341527f805          betty blowtorch  2137
# 1  f2fb0ff0-5679-42ec-a55c-15109ce6e320                die Ärzte  1099
# 2  b3ae82c2-e60b-4551-a76d-6620f1b456aa        melissa etheridge   897
# 3  3d6bbeb7-f90e-4d10-b440-e153c0d10b53                elvenking   717
# 4  bbd2ffd7-17f4-4506-8572-c1ea58c3f9a8     juliette & the licks   706
# 5  8bfac288-ccc5-448d-9573-c33ea2aa5c30    red hot chili peppers   691
# 6  6531c8b1-76ea-4141-b270-eb1ac5b41375                   magica   545
# 7  21f3573f-10cf-44b3-aeaa-26cccd8448b5  the black dahlia murder   507
# 8  c5db90c4-580d-4f33-b364-fbaa5a3a58b5              the murmurs   424
# 9  0639533a-0402-40ba-b6e0-18b067198b73               lunachicks   403

# %%
# 사용하는 컬럼만 남겨줍니다.
using_cols = ['user_id', 'artist', 'play']
data = data[using_cols]
data.head(10)
# Out:
#                                     user_id                   artist  play
# 0  00000c289a1829a808ac09c00daf10bc3c4e223b          betty blowtorch  2137
# 1  00000c289a1829a808ac09c00daf10bc3c4e223b                die Ärzte  1099
# 2  00000c289a1829a808ac09c00daf10bc3c4e223b        melissa etheridge   897
# 3  00000c289a1829a808ac09c00daf10bc3c4e223b                elvenking   717
# 4  00000c289a1829a808ac09c00daf10bc3c4e223b     juliette & the licks   706
# 5  00000c289a1829a808ac09c00daf10bc3c4e223b    red hot chili peppers   691
# 6  00000c289a1829a808ac09c00daf10bc3c4e223b                   magica   545
# 7  00000c289a1829a808ac09c00daf10bc3c4e223b  the black dahlia murder   507
# 8  00000c289a1829a808ac09c00daf10bc3c4e223b              the murmurs   424
# 9  00000c289a1829a808ac09c00daf10bc3c4e223b               lunachicks   403

# %%
# 소문자
data['artist'] = data['artist'].str.lower() # 검색을 쉽게 하기 위해 아티스트 문자열을 소문자로 바꿔줍시다.
data.tail(50)
# Out:
#                                            user_id                    artist  \
# 17535605  ffff9ef87a7d9494ada2f9ade4b9ff637c0759ac               lamb of god
# 17535606  ffff9ef87a7d9494ada2f9ade4b9ff637c0759ac               dragonforce
# 17535607                              sep 20, 2008            arctic monkeys
# 17535608                              sep 20, 2008          late of the pier
# 17535609                              sep 20, 2008                 bonaparte
# 17535610                              sep 20, 2008               1000 robota
# 17535611                              sep 20, 2008                     foals
# 17535612                              sep 20, 2008          bromheads jacket
# 17535613                              sep 20, 2008       bombay bicycle club
# 17535614                              sep 20, 2008                bloc party
# 17535615                              sep 20, 2008                     tomte
# 17535616                              sep 20, 2008            friendly fires
# 17535617                              sep 20, 2008               jack peñate
# 17535618                              sep 20, 2008           vampire weekend
# 17535619                              sep 20, 2008                 blackmail
# 17535620                              sep 20, 2008                 the coral
# 17535621                              sep 20, 2008                  interpol
# 17535622                              sep 20, 2008                beatsteaks
# 17535623                              sep 20, 2008                   klaxons
# 17535624                              sep 20, 2008           crystal castles
# 17535625                              sep 20, 2008               the strokes
# 17535626                              sep 20, 2008             kings of leon
# 17535627                              sep 20, 2008               arcade fire
# 17535628                              sep 20, 2008         tokyo police club
# 17535629                              sep 20, 2008            the ting tings
# 17535630                              sep 20, 2008     eagles of death metal
# 17535631                              sep 20, 2008  rage against the machine
# 17535632                              sep 20, 2008                  johnossi
# 17535633                              sep 20, 2008           franz ferdinand
# 17535634                              sep 20, 2008             cold war kids
# 17535635                              sep 20, 2008                      mgmt
# 17535636                              sep 20, 2008              test icicles
# 17535637                              sep 20, 2008               beachy head
# 17535638                              sep 20, 2008                  chikinki
# 17535639                              sep 20, 2008                   kilians
# 17535640                              sep 20, 2008            kiss kiss kill
# 17535641                              sep 20, 2008                 the kooks
# 17535642                              sep 20, 2008             the teenagers
# 17535643                              sep 20, 2008                    clueso
# 17535644                              sep 20, 2008                downstairs
# 17535645                              sep 20, 2008                  malajube
# 17535646                              sep 20, 2008                 radiohead
# 17535647                              sep 20, 2008                  the cure
# 17535648                              sep 20, 2008        these new puritans
# 17535649                              sep 20, 2008                the stills
# 17535650                              sep 20, 2008                turbostaat
# 17535651                              sep 20, 2008             cuba missouri
# 17535652                              sep 20, 2008           little man tate
# 17535653                              sep 20, 2008                 sigur rós
# 17535654                              sep 20, 2008                the smiths
#
#           play
# 17535605    58
# 17535606    57
# 17535607   158
# 17535608   131
# 17535609    93
# 17535610    54
# 17535611    54
# 17535612    51
# 17535613    46
# 17535614    45
# 17535615    45
# 17535616    43
# 17535617    40
# 17535618    39
# 17535619    36
# 17535620    36
# 17535621    35
# 17535622    34
# 17535623    32
# 17535624    31
# 17535625    30
# 17535626    27
# 17535627    26
# 17535628    25
# 17535629    24
# 17535630    23
# 17535631    23
# 17535632    21
# 17535633    20
# 17535634    19
# 17535635    18
# 17535636    16
# 17535637    15
# 17535638    14
# 17535639    14
# 17535640    14
# 17535641    14
# 17535642    14
# 17535643    12
# 17535644    12
# 17535645    12
# 17535646    12
# 17535647    12
# 17535648    12
# 17535649    12
# 17535650    12
# 17535651    11
# 17535652    11
# 17535653    10
# 17535654    10

# %%
# 1번 사용자의 가수 목록
condition = (data['user_id']== data.loc[0, 'user_id'])
data.loc[condition].head()
# Out:
#                                     user_id                artist  play
# 0  00000c289a1829a808ac09c00daf10bc3c4e223b       betty blowtorch  2137
# 1  00000c289a1829a808ac09c00daf10bc3c4e223b             die ärzte  1099
# 2  00000c289a1829a808ac09c00daf10bc3c4e223b     melissa etheridge   897
# 3  00000c289a1829a808ac09c00daf10bc3c4e223b             elvenking   717
# 4  00000c289a1829a808ac09c00daf10bc3c4e223b  juliette & the licks   706

# %%
# 유저 수
data['user_id'].nunique()
# Out:
# 358868

# %%
# 아티스트 수
data['artist'].nunique()
# Out:
# 291346

# %%
# 인기 많은 아티스트
artist_count = data.groupby('artist')['user_id'].count()
artist_count.sort_values(ascending=False).head(30)
# Out:
# artist
# radiohead                77254
# the beatles              76245
# coldplay                 66658
# red hot chili peppers    48924
# muse                     46954
# metallica                45233
# pink floyd               44443
# the killers              41229
# linkin park              39773
# nirvana                  39479
# system of a down         37267
# queen                    34174
# u2                       33206
# daft punk                33001
# the cure                 32624
# led zeppelin             32295
# placebo                  32072
# depeche mode             31916
# david bowie              31862
# bob dylan                31799
# death cab for cutie      31482
# arctic monkeys           30348
# foo fighters             30144
# air                      29795
# the rolling stones       29754
# nine inch nails          28946
# sigur rós                28901
# green day                28732
# massive attack           28691
# moby                     28232
# Name: user_id, dtype: int64

# %%
# 유저별 몇 명의 아티스트를 듣고 있는지에 대한 통계
user_count = data.groupby('user_id')['artist'].count()
user_count.describe()
# Out:
# count    358868.000000
# mean         48.863234
# std           8.524272
# min           1.000000
# 25%          46.000000
# 50%          49.000000
# 75%          51.000000
# max         166.000000
# Name: artist, dtype: float64

# %%
# 유저별 play횟수 중앙값에 대한 통계
user_median = data.groupby('user_id')['play'].median()
user_median.describe()
# Out:
# count    358868.000000
# mean        142.187676
# std         213.089902
# min           1.000000
# 25%          32.000000
# 50%          83.000000
# 75%         180.000000
# max       50142.000000
# Name: play, dtype: float64

# %%
# 본인이 좋아하시는 아티스트 데이터로 바꿔서 추가하셔도 됩니다! 단, 이름은 꼭 데이터셋에 있는 것과 동일하게 맞춰주세요. 
my_favorite = ['black eyed peas' , 'maroon5' ,'jason mraz' ,'coldplay' ,'beyoncé']

# 'zimin'이라는 user_id가 위 아티스트의 노래를 30회씩 들었다고 가정하겠습니다.
my_playlist = pd.DataFrame({'user_id': ['zimin']*5, 'artist': my_favorite, 'play':[30]*5})

if not data.isin({'user_id':['zimin']})['user_id'].any():  # user_id에 'zimin'이라는 데이터가 없다면
    data = data.append(my_playlist)                           # 위에 임의로 만든 my_favorite 데이터를 추가해 줍니다. 

data.tail(10)       # 잘 추가되었는지 확인해 봅시다.
# Out:
#                user_id           artist  play
# 17535650  sep 20, 2008       turbostaat    12
# 17535651  sep 20, 2008    cuba missouri    11
# 17535652  sep 20, 2008  little man tate    11
# 17535653  sep 20, 2008        sigur rós    10
# 17535654  sep 20, 2008       the smiths    10
# 0                zimin  black eyed peas    30
# 1                zimin          maroon5    30
# 2                zimin       jason mraz    30
# 3                zimin         coldplay    30
# 4                zimin          beyoncé    30

# %%
# 고유한 유저, 아티스트를 찾아내는 코드
user_unique = data['user_id'].unique()
artist_unique = data['artist'].unique()

# 유저, 아티스트 indexing 하는 코드 idx는 index의 약자입니다.
user_to_idx = {v:k for k,v in enumerate(user_unique)}
artist_to_idx = {v:k for k,v in enumerate(artist_unique)}

# %%
artist_to_idx
# Out:
# {'betty blowtorch': 0,
#  'die ärzte': 1,
#  'melissa etheridge': 2,
#  'elvenking': 3,
#  'juliette & the licks': 4,
#  'red hot chili peppers': 5,
#  'magica': 6,
#  'the black dahlia murder': 7,
#  'the murmurs': 8,
#  'lunachicks': 9,
#  'walls of jericho': 10,
#  'letzte instanz': 11,
#  'goldfrapp': 12,
#  'horrorpops': 13,
#  'the butchies': 14,
#  'jack off jill': 15,
#  'babes in toyland': 16,
#  'dropkick murphys': 17,
#  'all:my:faults': 18,
#  'le tigre': 19,
#  'schandmaul': 20,
#  'edguy': 21,
#  'maximum the hormone': 22,
#  'all ends': 23,
#  'jack johnson': 24,
#  'eluveitie': 25,
#  'rasputina': 26,
#  'london after midnight': 27,
#  'the killers': 28,
#  'mutyumu': 29,
#  'judas priest': 30,
#  'rob zombie': 31,
#  'the bosshoss': 32,
#  'blue öyster cult': 33,
#  'sandra nasic': 34,
#  'john mayer': 35,
#  'sleater-kinney': 36,
#  'the who': 37,
#  'disciple': 38,
#  'tanzwut': 39,
#  'guano apes': 40,
#  'the rolling stones': 41,
#  'little big town': 42,
#  'team dresch': 43,
#  'betty': 44,
#  'l7': 45,
#  'bif naked': 46,
#  'girlschool': 47,
#  'the wallflowers': 48,
#  'the most serene republic': 49,
#  'stars': 50,
#  'broken social scene': 51,
#  'have heart': 52,
#  'luminous orange': 53,
#  'boris': 54,
#  'arctic monkeys': 55,
#  'bright eyes': 56,
#  'coaltar of the deepers': 57,
#  'polar bear club': 58,
#  'the libertines': 59,
#  'death from above 1979': 60,
#  'owl city': 61,
#  'coldplay': 62,
#  'okkervil river': 63,
#  'jim sturgess': 64,
#  'deerhoof': 65,
#  'fear before the march of flames': 66,
#  'breathe carolina': 67,
#  'mstrkrft': 68,
#  'arcade fire': 69,
#  'the strokes': 70,
#  'cancer bats': 71,
#  'the honorary title': 72,
#  'michio kurihara': 73,
#  'mgmt': 74,
#  'queen': 75,
#  'the secret handshake': 76,
#  'animal collective': 77,
#  'heavy heavy low low': 78,
#  'hot hot heat': 79,
#  'hadouken!': 80,
#  'the wombats': 81,
#  'ai aso': 82,
#  'boris with michio kurihara': 83,
#  'uffie': 84,
#  'the last shadow puppets': 85,
#  'boys noize': 86,
#  'built to spill': 87,
#  'nujabes': 88,
#  'the rocket summer': 89,
#  'little dragon': 90,
#  'boris with merzbow': 91,
#  'the album leaf': 92,
#  'the microphones': 93,
#  'simian mobile disco': 94,
#  'm.i.a.': 95,
#  'death cab for cutie': 96,
#  'patrick wolf': 97,
#  'the fiery furnaces': 98,
#  'digitalism': 99,
#  'current 93': 100,
#  'coil': 101,
#  'andrew liles': 102,
#  'six organs of admittance': 103,
#  '16 horsepower': 104,
#  'angels of light': 105,
#  'the legendary pink dots': 106,
#  'charalambides': 107,
#  'festival': 108,
#  'fern knight': 109,
#  'nick cave & the bad seeds': 110,
#  'fovea hex': 111,
#  'amanda rogers': 112,
#  'lux interna': 113,
#  'nalle': 114,
#  'antony and the johnsons': 115,
#  'marissa nadler': 116,
#  'a silver mt. zion': 117,
#  'einstürzende neubauten': 118,
#  'marc almond': 119,
#  'mariee sioux': 120,
#  'björk': 121,
#  'bill fay': 122,
#  'nurse with wound': 123,
#  'baby dee': 124,
#  'ghq': 125,
#  'daniel higgs': 126,
#  'flairck': 127,
#  'jack rose': 128,
#  'castanets': 129,
#  'john jacob niles': 130,
#  'the revolutionary army of the infant jesus': 131,
#  'carter tutti': 132,
#  'the one ensemble': 133,
#  'orion rigel dommisse': 134,
#  'jocelyn pook': 135,
#  'matmos': 136,
#  'ulver': 137,
#  'ane brun': 138,
#  'soisong': 139,
#  'a hawk and a hacksaw': 140,
#  'frank london': 141,
#  'michael gira': 142,
#  'larkin grimm': 143,
#  'pelt': 144,
#  'jean parlette': 145,
#  'opeth': 146,
#  'cannibal corpse': 147,
#  'elis': 148,
#  'amoral': 149,
#  'amon amarth': 150,
#  'riverside': 151,
#  'dark tranquillity': 152,
#  'atrocity': 153,
#  'kromlek': 154,
#  'kamelot': 155,
#  'novembers doom': 156,
#  'poe': 157,
#  'rock universal': 158,
#  'dido': 159,
#  'stone temple pilots': 160,
#  'audioslave': 161,
#  'katatonia': 162,
#  'ark': 163,
#  'circus maximus': 164,
#  'dimmu borgir': 165,
#  'death': 166,
#  'månegarm': 167,
#  'cynic': 168,
#  'korpiklaani': 169,
#  'my dying bride': 170,
#  'brujeria': 171,
#  'agalloch': 172,
#  'alice in chains': 173,
#  'johann sebastian bach': 174,
#  'kalmah': 175,
#  'farmakon': 176,
#  'children of bodom': 177,
#  'dragonforce': 178,
#  'dredg': 179,
#  'green carnation': 180,
#  'pain of salvation': 181,
#  'rhapsody of fire': 182,
#  'the mars volta': 183,
#  'tool': 184,
#  'arch enemy': 185,
#  'at the gates': 186,
#  'compay segundo': 187,
#  'ensiferum': 188,
#  'naglfar': 189,
#  'nevermore': 190,
#  'old mans child': 191,
#  'shade empire': 192,
#  'system of a down': 193,
#  'tristania': 194,
#  'devendra banhart': 195,
#  'boards of canada': 196,
#  'cocorosie': 197,
#  'aphex twin': 198,
#  'atmosphere': 199,
#  'joanna newsom': 200,
#  'air': 201,
#  'portishead': 202,
#  'massive attack': 203,
#  'plaid': 204,
#  'fog': 205,
#  'prefuse 73': 206,
#  'm83': 207,
#  'the flashbulb': 208,
#  'pavement': 209,
#  'amon tobin': 210,
#  'sage francis': 211,
#  'four tet': 212,
#  'brother ali': 213,
#  'max richter': 214,
#  'why?': 215,
#  'autechre': 216,
#  'radiohead': 217,
#  'susumu yokota': 218,
#  'electrelane': 219,
#  'neutral milk hotel': 220,
#  'bent': 221,
#  'vetiver': 222,
#  'k-the-i???': 223,
#  'illogic': 224,
#  'annie': 225,
#  'broadcast': 226,
#  'beastie boys': 227,
#  'aesop rock': 228,
#  'mf doom': 229,
#  'the books': 230,
#  'bibio': 231,
#  "rachel's": 232,
#  'architecture in helsinki': 233,
#  'bola': 234,
#  'isan': 235,
#  'apes & androids': 236,
#  'múm': 237,
#  'elliott smith': 238,
#  'caribou': 239,
#  'the hold steady': 240,
#  'mogwai': 241,
#  'justice': 242,
#  'sigur rós': 243,
#  'clutch': 244,
#  'white denim': 245,
#  'the go! team': 246,
#  'the beatles': 247,
#  "2 many dj's": 248,
#  'tv on the radio': 249,
#  'kyuss': 250,
#  'dj shadow': 251,
#  'a tribe called quest': 252,
#  'the cinematic orchestra': 253,
#  'beck': 254,
#  'bon iver': 255,
#  'röyksopp': 256,
#  'rex the dog': 257,
#  'bonobo': 258,
#  'deadmau5': 259,
#  'the decemberists': 260,
#  'earth': 261,
#  'snow patrol': 262,
#  'battles': 263,
#  'metronomy': 264,
#  'dj format': 265,
#  'the prodigy': 266,
#  'lemon jelly': 267,
#  'pink floyd': 268,
#  'rjd2': 269,
#  'the flaming lips': 270,
#  'alasdair fraser & paul machlis': 271,
#  'passion pit': 272,
#  'holy fuck': 273,
#  'michael jackson': 274,
#  'late of the pier': 275,
#  'flight of the conchords': 276,
#  'muse': 277,
#  'fleetwood mac': 278,
#  'led zeppelin': 279,
#  'stam1na': 280,
#  'dream theater': 281,
#  'ac/dc': 282,
#  'metallica': 283,
#  'iron maiden': 284,
#  'bob marley & the wailers': 285,
#  'megadeth': 286,
#  'trivium': 287,
#  'raappana': 288,
#  'nightwish': 289,
#  'kotiteollisuus': 290,
#  'sublime': 291,
#  'viikate': 292,
#  'volbeat': 293,
#  "guns n' roses": 294,
#  'bon jovi': 295,
#  'dio': 296,
#  'soldiers of jah army': 297,
#  'scorpions': 298,
#  'teräsbetoni': 299,
#  'nopsajalka': 300,
#  'paramore': 301,
#  'the darkness': 302,
#  'soul captain band': 303,
#  'asa': 304,
#  'tarot': 305,
#  'klamydia': 306,
#  'gentleman': 307,
#  'mötley crüe': 308,
#  'manowar': 309,
#  'killswitch engage': 310,
#  'slayer': 311,
#  'in flames': 312,
#  'skid row': 313,
#  'stone': 314,
#  'bullet for my valentine': 315,
#  'mokoma': 316,
#  'pantera': 317,
#  'brother firetribe': 318,
#  'hurriganes': 319,
#  'norther': 320,
#  'stratovarius': 321,
#  'kiuas': 322,
#  'ozzy osbourne': 323,
#  'pin': 324,
#  'feel': 325,
#  'elton john': 326,
#  'orgy': 327,
#  'brandy': 328,
#  'pet shop boys': 329,
#  'sade': 330,
#  'belinda carlisle': 331,
#  'eurythmics': 332,
#  'mike oldfield': 333,
#  'hall & oates': 334,
#  'chris rea': 335,
#  'laura branigan': 336,
#  'the waterboys': 337,
#  'maciej silski': 338,
#  'leona lewis': 339,
#  'george michael': 340,
#  'black': 341,
#  'frozen silence': 342,
#  'sweet coffee': 343,
#  'blackfield': 344,
#  'cyndi lauper': 345,
#  'pseudo echo': 346,
#  'desireless': 347,
#  'limp bizkit': 348,
#  'modern talking': 349,
#  'rihanna': 350,
#  'a-ha': 351,
#  'linkin park': 352,
#  'hans zimmer': 353,
#  'nelly furtado': 354,
#  'madonna': 355,
#  'blink-182': 356,
#  'dave gahan': 357,
#  'kelly clarkson': 358,
#  'lucie silvas': 359,
#  'natalie imbruglia': 360,
#  'michelle branch': 361,
#  'delta goodrem': 362,
#  'new order': 363,
#  'seal': 364,
#  'atomic kitten': 365,
#  'backstreet boys': 366,
#  'mary j. blige': 367,
#  'negative': 368,
#  'justin timberlake': 369,
#  'savage garden': 370,
#  'nerina pallot': 371,
#  'erasure': 372,
#  'culture club': 373,
#  'mr. oizo': 374,
#  'robbie williams': 375,
#  'black eyed peas': 376,
#  'antonio orozco': 377,
#  'decai': 378,
#  'kiko & shara': 379,
#  'marc anthony': 380,
#  'manuel carrasco': 381,
#  'mika': 382,
#  'juanes': 383,
#  'la oreja de van gogh': 384,
#  'melendi': 385,
#  'amaral': 386,
#  'andy & lucas': 387,
#  'chambao': 388,
#  'chayanne': 389,
#  'christian castro': 390,
#  'christina aguilera': 391,
#  'craig david': 392,
#  'luis fonsi': 393,
#  'sergio contreras': 394,
#  'ana torroja': 395,
#  'beyoncé': 396,
#  'bustamante': 397,
#  'camila': 398,
#  'colbie caillat': 399,
#  'coti': 400,
#  'david bisbal': 401,
#  'edurne': 402,
#  'fito & fitipaldis': 403,
#  'hanna': 404,
#  'malu': 405,
#  'paulina rubio': 406,
#  'rosana': 407,
#  't.a.t.u.': 408,
#  'amy winehouse': 409,
#  'efecto mariposa': 410,
#  'el arrebato': 411,
#  'enrique iglesias': 412,
#  'fondo flamenco': 413,
#  'jennifer lopez': 414,
#  'mecano': 415,
#  'phil collins': 416,
#  'sean kingston': 417,
#  'u2': 418,
#  'dub fx': 419,
#  'box car racer': 420,
#  'zebrahead': 421,
#  'paul oakenfold': 422,
#  'pendulum': 423,
#  'ronald jenkees': 424,
#  'sum 41': 425,
#  'angels & airwaves': 426,
#  'haggard': 427,
#  'alien ant farm': 428,
#  'the offspring': 429,
#  'океан ельзи': 430,
#  'ronan hardiman': 431,
#  'the crystal method': 432,
#  '川田まみ': 433,
#  'eminem': 434,
#  'the qemists': 435,
#  'silverstein': 436,
#  'rise against': 437,
#  'бумбокс': 438,
#  'scum of the earth': 439,
#  'blu mar ten': 440,
#  'bomfunk mcs': 441,
#  'vanessa-mae': 442,
#  'тартак': 443,
#  'drop dead, gorgeous': 444,
#  'flying steps': 445,
#  'drumattic twins': 446,
#  'andrew w.k.': 447,
#  'hoobastank': 448,
#  'dover': 449,
#  'bodyjar': 450,
#  'southside rockers': 451,
#  'prodigy': 452,
#  'future prophecies': 453,
#  'jonathan coulton': 454,
#  'blessthefall': 455,
#  'nubreed & luke chable': 456,
#  'franz ferdinand': 457,
#  'johannes linstead': 458,
#  'infected mushroom': 459,
#  'darude': 460,
#  'akira yamaoka': 461,
#  'aqua': 462,
#  'clawfinger': 463,
#  'dusty kid': 464,
#  'senses fail': 465,
#  'commix': 466,
#  'id software': 467,
#  'panic at the disco': 468,
#  'enigma': 469,
#  'fatboy slim': 470,
#  'krs-one': 471,
#  'drowning pool': 472,
#  'placebo': 473,
#  'david & the citizens': 474,
#  'kent': 475,
#  'säkert!': 476,
#  'detektivbyrån': 477,
#  'lars winnerbäck': 478,
#  'raymond & maria': 479,
#  'tegan and sara': 480,
#  'the knife': 481,
#  'tiger lou': 482,
#  'håkan hellström': 483,
#  'david fridlund': 484,
#  'the ark': 485,
#  'alice in videoland': 486,
#  'timo räisänen': 487,
#  'the cardigans': 488,
#  'bloc party': 489,
#  'oasis': 490,
#  'sahara hotnights': 491,
#  'vapnet': 492,
#  'laleh': 493,
#  'markus krunegård': 494,
#  'the kooks': 495,
#  'deportees': 496,
#  'r.e.m.': 497,
#  'slagsmålsklubben': 498,
#  'hot chip': 499,
#  'millencolin': 500,
#  'the sounds': 501,
#  'mew': 502,
#  'green day': 503,
#  'kings of convenience': 504,
#  'firefox ak': 505,
#  'mando diao': 506,
#  'the tough alliance': 507,
#  'shout out louds': 508,
#  'keane': 509,
#  'wir sind helden': 510,
#  'thompson twins': 511,
#  'hanson': 512,
#  'no doubt': 513,
#  'orchestral manoeuvres in the dark': 514,
#  'the human league': 515,
#  'altered images': 516,
#  'martina mcbride': 517,
#  'yazoo': 518,
#  'regina spektor': 519,
#  'the format': 520,
#  'carolyn dawn johnson': 521,
#  'mazzy star': 522,
#  'dashboard confessional': 523,
#  'jonathan larson': 524,
#  'wicked': 525,
#  'the verve pipe': 526,
#  'missing persons': 527,
#  'the passions': 528,
#  'ima robot': 529,
#  'judith holofernes': 530,
#  'depeche mode': 531,
#  'fake': 532,
#  'der plan': 533,
#  'gwen stefani': 534,
#  'dierks bentley': 535,
#  'heaven 17': 536,
#  'the sundays': 537,
#  'dixie chicks': 538,
#  'shania twain': 539,
#  'stacey q': 540,
#  'camera obscura': 541,
#  'deana carter': 542,
#  'matt & kim': 543,
#  'steel train': 544,
#  'dan fogelberg': 545,
#  'taking back sunday': 546,
#  'andrew bird': 547,
#  'jewel': 548,
#  'haircut 100': 549,
#  'britney spears': 550,
#  'kristy lee': 551,
#  'the police': 552,
#  'the postal service': 553,
#  'fefe dobson': 554,
#  'julie roberts': 555,
#  'j dilla': 556,
#  'nas': 557,
#  'common': 558,
#  'black milk': 559,
#  'pete rock': 560,
#  'jay-z': 561,
#  'dr. dre': 562,
#  'evidence': 563,
#  'kanye west': 564,
#  'dead prez': 565,
#  'percee p': 566,
#  'jeff mills': 567,
#  'method man': 568,
#  'panacea': 569,
#  '2pac': 570,
#  'fort minor': 571,
#  'madvillain': 572,
#  'ratatat': 573,
#  'talib kweli': 574,
#  'do or die': 575,
#  'madlib': 576,
#  '50 cent': 577,
#  'abstract rude & tribe unique': 578,
#  'the alchemist': 579,
#  'bill evans': 580,
#  'gza/genius': 581,
#  'lil wayne': 582,
#  'styles p': 583,
#  'emc': 584,
#  'ghostface': 585,
#  'k-os': 586,
#  'burial': 587,
#  'dj vadim': 588,
#  'el-p': 589,
#  'big shug': 590,
#  'black spade': 591,
#  'john coltrane': 592,
#  'the residents': 593,
#  'roni size & reprazent': 594,
#  'flying lotus - (www.influencias-urbanas.blogspot.com)': 595,
#  'the cool kids': 596,
#  'the game': 597,
#  'redman': 598,
#  'rza': 599,
#  'joan baez': 600,
#  'e-rotic': 601,
#  'goo goo dolls': 602,
#  'apulanta': 603,
#  'chorale': 604,
#  'bryan adams': 605,
#  'gnarls barkley': 606,
#  'groove coverage': 607,
#  'september': 608,
#  '3 doors down': 609,
#  'basic element': 610,
#  'chris brown': 611,
#  'eels': 612,
#  'solid base': 613,
#  'irwin goodman': 614,
#  'moby': 615,
#  'don huonot': 616,
#  'stella': 617,
#  'the pussycat dolls': 618,
#  'cascada': 619,
#  'john legend': 620,
#  'alicia keys': 621,
#  'kapasiteettiyksikkö': 622,
#  'sonata arctica': 623,
#  'frank sinatra': 624,
#  'jonas brothers': 625,
#  'deep insight': 626,
#  'maroon 5': 627,
#  'the calling': 628,
#  'ambassadöör': 629,
#  'cheek': 630,
#  'darin': 631,
#  'antti tuisku': 632,
#  'usher': 633,
#  'finlanders': 634,
#  'sadetanssi': 635,
#  'snoop dogg': 636,
#  'akon': 637,
#  'mamba': 638,
#  'da buzz': 639,
#  'jessy': 640,
#  'syd barrett': 641,
#  'spiritualized': 642,
#  'the boo radleys': 643,
#  'the brian jonestown massacre': 644,
#  'black rebel motorcycle club': 645,
#  'the duke spirit': 646,
#  'the stone roses': 647,
#  'jefferson airplane': 648,
#  'the black angels': 649,
#  'graham bond organisation': 650,
#  'love': 651,
#  'the warlocks': 652,
#  'a place to bury strangers': 653,
#  'not from there': 654,
#  'richard in your mind': 655,
#  'king khan & the shrines': 656,
#  'the stairs': 657,
#  'the vera violets': 658,
#  "edgar 'jones' jones": 659,
#  'film school': 660,
#  'captain beefheart & his magic band': 661,
#  'the charlatans': 662,
#  'kaleidoscope': 663,
#  'the raconteurs': 664,
#  'dungen': 665,
#  'the velvet underground': 666,
#  'spindrift': 667,
#  'the incredible string band': 668,
#  'flavor crystals': 669,
#  'nico': 670,
#  'the dandy warhols': 671,
#  'asobi seksu': 672,
#  'stereolab': 673,
#  'fairport convention': 674,
#  'nick drake': 675,
#  'soft machine': 676,
#  'the greenhornes': 677,
#  'the national': 678,
#  'black mountain': 679,
#  'television': 680,
#  'the telescopes': 681,
#  'lostprophets': 682,
#  'all time low': 683,
#  'lucky boys confusion': 684,
#  'amber pacific': 685,
#  'four year strong': 686,
#  'fall out boy': 687,
#  'the weakerthans': 688,
#  'showoff': 689,
#  '+44': 690,
#  'damien rice': 691,
#  'my chemical romance': 692,
#  'ben kweller': 693,
#  'foo fighters': 694,
#  'anberlin': 695,
#  'moving mountains': 696,
#  'the wedding': 697,
#  'frightened rabbit': 698,
#  'cartel': 699,
#  'saosin': 700,
#  'set your goals': 701,
#  'holiday parade': 702,
#  'cauterize': 703,
#  'nizlopi': 704,
#  'hit the lights': 705,
#  'get cape. wear cape. fly': 706,
#  'better luck next time': 707,
#  'girl talk': 708,
#  'story of the year': 709,
#  'joshua radin': 710,
#  'the frantic': 711,
#  'the ataris': 712,
#  'sufjan stevens': 713,
#  'sherwood': 714,
#  'norah jones': 715,
#  'madredeus': 716,
#  'așa': 717,
#  'carla bruni': 718,
#  'penguin cafe orchestra': 719,
#  'ravid goldschmidt': 720,
#  'humanos': 721,
#  'xutos & pontapés': 722,
#  'paul simon': 723,
#  'lily allen': 724,
#  'kid loco': 725,
#  'pedro abrunhosa': 726,
#  'stevie wonder': 727,
#  'thievery corporation': 728,
#  'the streets': 729,
#  'ratos de porão': 730,
#  'lady sovereign': 731,
#  'faith no more': 732,
#  'manu chao': 733,
#  'tenacious d': 734,
#  'fantômas': 735,
#  'type o negative': 736,
#  'pearl jam': 737,
#  'cali lewis': 738,
#  'the commitments': 739,
#  'soundgarden': 740,
#  'buckethead': 741,
#  'the cult': 742,
#  'rush': 743,
#  'king crimson': 744,
#  'camel': 745,
#  'amplifier': 746,
#  'uriah heep': 747,
#  'the answer': 748,
#  'yes': 749,
#  'disturbed': 750,
#  'jethro tull': 751,
#  'porcupine tree': 752,
#  'liquid tension experiment': 753,
#  'ted nugent': 754,
#  'wolfmother': 755,
#  'emerson, lake & palmer': 756,
#  'aerosmith': 757,
#  'iommi': 758,
#  'frankie goes to hollywood': 759,
#  'ufo': 760,
#  'days of the new': 761,
#  'caravan': 762,
#  'the verve': 763,
#  'rammstein': 764,
#  'wishbone ash': 765,
#  'the moody blues': 766,
#  'jordan rudess': 767,
#  'chevelle': 768,
#  'cream': 769,
#  'patti smith': 770,
#  'nickelback': 771,
#  'zz top': 772,
#  'nine inch nails': 773,
#  'my bloody valentine': 774,
#  'pj harvey': 775,
#  'the cure': 776,
#  'nick cave and the bad seeds': 777,
#  'the jesus and mary chain': 778,
#  'the sisters of mercy': 779,
#  'david bowie': 780,
#  'a perfect circle': 781,
#  'the white stripes': 782,
#  'the dresden dolls': 783,
#  'nouvelle vague': 784,
#  'leonard cohen': 785,
#  'rowland s. howard': 786,
#  'creedence clearwater revival': 787,
#  'goon moon': 788,
#  'grinderman': 789,
#  'gary numan': 790,
#  'slowdive': 791,
#  'the boys next door': 792,
#  'beirut': 793,
#  'joy division': 794,
#  'clint mansell': 795,
#  'inkubus sukkubus': 796,
#  'the smiths': 797,
#  'cat power': 798,
#  'nick cave & warren ellis': 799,
#  'anita lane': 800,
#  'bauhaus': 801,
#  'amiina': 802,
#  'bajaga': 803,
#  'interpol': 804,
#  'the 69 eyes': 805,
#  'christian death': 806,
#  'the stooges': 807,
#  'iggy pop': 808,
#  'grave digger': 809,
#  'running wild': 810,
#  'primal fear': 811,
#  'paragon': 812,
#  'iced earth': 813,
#  'lamb of god': 814,
#  'u.d.o.': 815,
#  'annihilator': 816,
#  'exodus': 817,
#  'exciter': 818,
#  'strapping young lad': 819,
#  'kreator': 820,
#  'rebellion': 821,
#  'sabaton': 822,
#  'helloween': 823,
#  'iron savior': 824,
#  'accept': 825,
#  '3 inches of blood': 826,
#  'jag panzer': 827,
#  'mastodon': 828,
#  'steel attack': 829,
#  'daath': 830,
#  'metal church': 831,
#  'gojira': 832,
#  'devildriver': 833,
#  'decapitated': 834,
#  'hammerfall': 835,
#  'the ocean': 836,
#  'hatebreed': 837,
#  'mortification': 838,
#  'halford': 839,
#  'meshuggah': 840,
#  'finntroll': 841,
#  'gamma ray': 842,
#  'stormwarrior': 843,
#  'fight': 844,
#  'vicious rumors': 845,
#  'dream evil': 846,
#  'necrophagist': 847,
#  'rage': 848,
#  'morgana lefay': 849,
#  'chiodos': 850,
#  'black tequila': 851,
#  '30 seconds to mars': 852,
#  'as i lay dying': 853,
#  'a static lullaby': 854,
#  'billy talent': 855,
#  'bosse': 856,
#  'deus': 857,
#  'feeder': 858,
#  'funeral for a friend': 859,
#  'a day to remember': 860,
#  'beatsteaks': 861,
#  'coheed and cambria': 862,
#  'dúné': 863,
#  'enter shikari': 864,
#  'finch': 865,
#  'from first to last': 866,
#  'lostalone': 867,
#  'mindless self indulgence': 868,
#  'olli schulz & der hund marie': 869,
#  'slut': 870,
#  'the dreaming': 871,
#  'alesana': 872,
#  'ash': 873,
#  'brand new': 874,
#  'canoe': 875,
#  'kill hannah': 876,
#  'madsen': 877,
#  'maxïmo park': 878,
#  'neaera': 879,
#  'scary kids scaring kids': 880,
#  'secret and whisper': 881,
#  'the fall of troy': 882,
#  'the vines': 883,
#  'virginia jetzt!': 884,
#  'as we fight': 885,
#  'grammatics': 886,
#  'tele': 887,
#  'underoath': 888,
#  'parragon books': 889,
#  'michael armstrong': 890,
#  'alkaline trio': 891,
#  'afi': 892,
#  'tiger army': 893,
#  'elvis costello': 894,
#  'elvis presley': 895,
#  'the mighty mighty bosstones': 896,
#  'adema': 897,
#  'foghat': 898,
#  'kylie minogue': 899,
#  'foxboro hot tubs': 900,
#  'pink': 901,
#  'tim mcgraw': 902,
#  'dead to me': 903,
#  'mxpx': 904,
#  'bad religion': 905,
#  'jimmy eat world': 906,
#  'the gaslight anthem': 907,
#  'danny elfman': 908,
#  'dead kennedys': 909,
#  'nirvana': 910,
#  'the tantra monsters': 911,
#  'poison': 912,
#  'me first and the gimme gimmes': 913,
#  'mgm studio orchestra': 914,
#  'new found glory': 915,
#  'agnostic front': 916,
#  'all': 917,
#  'marilyn manson': 918,
#  'rancid': 919,
#  'less than jake': 920,
#  'my life with the thrill kill kult': 921,
#  'the aquabats': 922,
#  'the distillers': 923,
#  'skarface': 924,
#  'mad caddies': 925,
#  'nofx': 926,
#  'cypress hill': 927,
#  'koяn': 928,
#  'the planet smashers': 929,
#  'reel big fish': 930,
#  'ska-p': 931,
#  'moskovskaya': 932,
#  'onyx': 933,
#  'belvedere': 934,
#  'distemper': 935,
#  'aventura': 936,
#  "5'nizza": 937,
#  'captain everything!': 938,
#  'bob marley': 939,
#  'slipknot': 940,
#  'alizée': 941,
#  'electrosoul system': 942,
#  'richard cheese': 943,
#  'avril lavigne': 944,
#  'otklonenie': 945,
#  'cidade negra': 946,
#  'talco': 947,
#  'f.p.g.': 948,
#  'the specials': 949,
#  'daddy yankee': 950,
#  'skaface': 951,
#  'tina charles': 952,
#  'yeah yeah yeahs': 953,
#  'the dead weather': 954,
#  'no age': 955,
#  'tiny masters of today': 956,
#  'japandroids': 957,
#  'the used': 958,
#  'veto': 959,
#  'friendly fires': 960,
#  'hateen': 961,
#  'onerepublic': 962,
#  'dead fish': 963,
#  'sixpence none the richer': 964,
#  'peter bjorn and john': 965,
#  'thursday': 966,
#  'weezer': 967,
#  'japanther': 968,
#  'kings of leon': 969,
#  "rock'n'zombie": 970,
#  'feist': 971,
#  'klaxons': 972,
#  'cansei de ser sexy': 973,
#  'does it offend you, yeah?': 974,
#  'twilight': 975,
#  'grease': 976,
#  'kaiser chiefs': 977,
#  'pelle miljoona': 978,
#  'ripsipiirakka': 979,
#  'orson': 980,
#  'frankie valli': 981,
#  'motion city soundtrack': 982,
#  'kuningas pähkinä & setä tamu': 983,
#  'genesis': 984,
#  'jukka poika': 985,
#  'technotronic': 986,
#  'robert pattinson': 987,
#  'stig dogg': 988,
#  'aviation': 989,
#  'high school musical 2': 990,
#  'kapteeni ä-ni': 991,
#  'ramones': 992,
#  'fools garden': 993,
#  'bone thugs-n-harmony': 994,
#  'rufus wainwright': 995,
#  'iron & wine': 996,
#  'blue foundation': 997,
#  'lemon ice': 998,
#  'the black ghosts': 999,
#  ...}

# %%
# 인덱싱이 잘 되었는지 확인해 봅니다. 
print(user_to_idx['zimin'])    # 358869명의 유저 중 마지막으로 추가된 유저이니 358868이 나와야 합니다. 
print(artist_to_idx['black eyed peas'])
# Out:
# 358868
# 376

# %%
# indexing을 통해 데이터 컬럼 내 값을 바꾸는 코드
# dictionary 자료형의 get 함수는 https://wikidocs.net/16 을 참고하세요.

# user_to_idx.get을 통해 user_id 컬럼의 모든 값을 인덱싱한 Series를 구해 봅시다. 
# 혹시 정상적으로 인덱싱되지 않은 row가 있다면 인덱스가 NaN이 될 테니 dropna()로 제거합니다. 
temp_user_data = data['user_id'].map(user_to_idx.get).dropna()
if len(temp_user_data) == len(data):   # 모든 row가 정상적으로 인덱싱되었다면
    print('user_id column indexing OK!!')
    data['user_id'] = temp_user_data   # data['user_id']을 인덱싱된 Series로 교체해 줍니다. 
else:
    print('user_id column indexing Fail!!')

# artist_to_idx을 통해 artist 컬럼도 동일한 방식으로 인덱싱해 줍니다. 
temp_artist_data = data['artist'].map(artist_to_idx.get).dropna()
if len(temp_artist_data) == len(data):
    print('artist column indexing OK!!')
    data['artist'] = temp_artist_data
else:
    print('artist column indexing Fail!!')

data
# Out:
# user_id column indexing OK!!
# artist column indexing OK!!
#     user_id  artist  play
# 0         0       0  2137
# 1         0       1  1099
# 2         0       2   897
# 3         0       3   717
# 4         0       4   706
# ..      ...     ...   ...
# 0    358868     376    30
# 1    358868  270115    30
# 2    358868    3746    30
# 3    358868      62    30
# 4    358868     396    30
#
# [17535660 rows x 3 columns]

# %%
# 1회만 play한 데이터의 비율을 보는 코드
only_one = data[data['play']<2]
one, all_data = len(only_one), len(data)
print(f'{one},{all_data}')
print(f'Ratio of only_one over all data is {one/all_data:.2%}')  # f-format에 대한 설명은 https://bit.ly/2DTLqYU
# Out:
# 147740,17535660
# Ratio of only_one over all data is 0.84%

# %% [markdown]
# ## 13-5. Matrix Factorization(MF)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 13-6. CSR(Compressed Sparse Row) Matrix

# %% [markdown]
# ![image.png](attachment:image.png)
#
# - data는 0이 아닌 원소를 차례로 기입한 값입니다.
#   data = [1, 2, 3, 4, 5, 6]
#
# - indices는 data의 각 요소가 어느 열(column)에 있는지를 표현한 index입니다.
#   indices = [0, 4, 1, 3, 0, 3]
#
# - indptr은 [최초시작행번호,시작행에서의 데이타 개수,두번째 행에서의 데이타 누적 개수,...,마지막행에서의 데이타 누적개수] 입니다. 이를 통해 data의 요소들이 어느 행(row)에 있는지를 알 수 있습니다.
#   indptr = [0, 2, 4, 4, 6]
#
# - 이를 통해 data[0:2]는 첫 번째 행, data[2:4]는 두 번째 행, data[4:4]는 세 번째 행, data[4:6]는 네 번째 행에 위치함을 나타낼 수 있게 됩니다.

# %%
# 실습 위에 설명보고 이해해서 만들어보기
from scipy.sparse import csr_matrix

num_user = data['user_id'].nunique()
num_artist = data['artist'].nunique()

csr_data = csr_matrix((data.play, (data.user_id, data.artist)), shape= (num_user, num_artist))
csr_data
# Out:
# <358869x291347 sparse matrix of type '<class 'numpy.int64'>'
# 	with 17535578 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ## 13-7. MF 모델 학습하기

# %% [markdown]
# 이전 스텝에서 설명한 Matrix Factorization 모델을 implicit 패키지를 사용하여 학습해 봅시다.
#
# - implicit 패키지는 이전 스텝에서 설명한 암묵적(implicit) dataset을 사용하는 다양한 모델을 굉장히 빠르게 학습할 수 있는 패키지입니다.
# - 이 패키지에 구현된 als(AlternatingLeastSquares) 모델을 사용하겠습니다. Matrix Factorization에서 쪼개진 두 Feature Matrix를 한꺼번에 훈련하는 것은 잘 수렴하지 않기 때문에, 한쪽을 고정시키고 다른 쪽을 학습하는 방식을 번갈아 수행하는 AlternatingLeastSquares 방식이 효과적인 것으로 알려져 있습니다.

# %%
from implicit.als import AlternatingLeastSquares
import os
import numpy as np

# implicit 라이브러리에서 권장하고 있는 부분입니다. 학습 내용과는 무관합니다.
os.environ['OPENBLAS_NUM_THREADS']='1'
os.environ['KMP_DUPLICATE_LIB_OK']='True'
os.environ['MKL_NUM_THREADS']='1'

# %% [markdown]
# AlternatingLeastSquares 클래스의 __init__ 파라미터를 살펴보겠습니다.
#
# - factors : 유저와 아이템의 벡터를 몇 차원으로 할 것인지
# - regularization : 과적합을 방지하기 위해 정규화 값을 얼마나 사용할 것인지
# - use_gpu : GPU를 사용할 것인지
# - iterations : epochs와 같은 의미입니다. 데이터를 몇 번 반복해서 학습할 것인지

# %%
# Implicit AlternatingLeastSquares 모델의 선언
als_model = AlternatingLeastSquares(factors=100
                                    , regularization=0.01
                                    , use_gpu=False
                                    , iterations=15  #epoch
                                    , dtype=np.float32
                                   )

# %%
# als 모델은 input으로 (item X user 꼴의 matrix를 받기 때문에 Transpose해줍니다.)
csr_data_transpose = csr_data.T
csr_data_transpose
# Out:
# <291347x358869 sparse matrix of type '<class 'numpy.int64'>'
# 	with 17535578 stored elements in Compressed Sparse Column format>

# %%
# 모델 훈련
als_model.fit(csr_data_transpose)
# Out:
#   0%|          | 0/15 [00:00<?, ?it/s]

# %%
zimin, black_eyed_peas = user_to_idx['zimin'], artist_to_idx['black eyed peas']
zimin_vector, black_eyed_peas_vector = als_model.user_factors[zimin], als_model.item_factors[black_eyed_peas]

print('슝=3')
# Out:
# 슝=3

# %%
zimin_vector
# Out:
# array([ 0.17395438,  0.8420694 , -0.8172087 ,  0.18121493,  0.33467725,
#         0.5245209 , -0.23029073,  0.740989  , -0.29040015,  0.7056608 ,
#        -0.29354253, -0.8031569 , -0.85113007,  1.2695256 , -0.26544216,
#        -0.71379447,  0.16187981, -0.7704634 , -0.04026514, -1.2222432 ,
#        -0.20732501, -0.9163469 ,  0.5651408 ,  0.1182632 ,  0.71280336,
#        -0.2976536 , -0.18803413,  0.08473604,  0.37097123, -0.18569365,
#         0.05535068,  0.75988275, -0.07449433,  0.19856015,  0.96875143,
#         0.2031026 ,  0.65176445,  0.47643697,  0.20128149,  1.0305101 ,
#        -1.233093  , -0.37455973,  0.02517342, -1.096175  , -0.6869525 ,
#         0.1690576 ,  0.81207514, -0.45674947, -0.32884485,  0.74207175,
#         1.329238  ,  0.12873039, -0.9431052 ,  1.0799553 , -0.10379532,
#        -1.036544  , -0.6365559 , -0.74160326,  0.03066146,  1.2538619 ,
#         0.02037125,  0.16046835,  0.46205935, -0.41465268,  0.60092944,
#        -1.0870963 ,  0.25142634, -0.11446028, -1.1505616 ,  0.11452769,
#         0.05063877,  0.32668763, -0.10380959, -0.04052104,  0.66051406,
#         0.30217487,  0.21169451,  1.9099909 ,  0.1275418 , -0.4481809 ,
#         0.2686333 ,  0.20547414,  0.36289558,  0.70118773,  0.08615717,
#        -0.5619035 ,  0.13070858,  0.8480452 , -0.69443667, -0.373469  ,
#        -0.56293523,  0.227162  , -0.76445866, -0.14631113,  0.14585355,
#         1.2889562 , -0.3285392 ,  0.8456474 , -0.78889316, -0.5174218 ],
#       dtype=float32)

# %%
black_eyed_peas_vector
# Out:
# array([ 1.11823007e-02,  1.83212999e-02, -2.87170336e-03,  2.05986071e-02,
#         2.03214884e-02,  2.74211802e-02, -6.55621756e-04,  4.28575417e-03,
#         2.66476790e-03,  1.67435706e-02, -4.67874575e-03,  6.24552369e-03,
#        -1.12711114e-03,  2.93292105e-02,  8.57162103e-03, -1.24205286e-02,
#         4.53138119e-03, -2.79592676e-03,  9.84701701e-03,  1.90298527e-03,
#        -2.12890049e-03,  3.88122979e-03,  1.09842382e-02,  2.00871341e-02,
#         6.40535960e-03, -5.29867131e-03,  8.89367145e-03,  6.25301898e-03,
#         6.43326668e-03, -5.78356767e-03,  7.97223649e-04,  1.11224065e-02,
#         1.06044570e-02,  3.69465351e-03,  1.63430758e-02,  9.88389459e-03,
#         2.67463587e-02,  1.41155673e-02,  2.10780427e-02, -3.66017292e-03,
#        -1.74122062e-02, -3.27930739e-03,  1.58802178e-02, -2.44143442e-03,
#        -1.74010731e-03,  1.09963920e-02,  7.07777962e-03, -1.83265714e-03,
#         1.88821051e-02,  6.84101600e-03,  2.25634072e-02,  1.77940372e-02,
#        -4.30159783e-03,  2.13523284e-02, -3.22610664e-04,  1.97296267e-05,
#         5.91521012e-03, -6.79003354e-03,  1.08108884e-02,  4.27776463e-02,
#         1.22713046e-02,  1.14297178e-02,  1.52462088e-02,  4.06809477e-03,
#         1.48437228e-02, -1.28299557e-02,  2.75390618e-03,  3.00427689e-03,
#        -5.60113648e-03, -4.72740084e-03,  2.53245123e-02,  9.05618945e-04,
#         1.54508147e-02,  3.34298494e-03,  8.92365724e-03,  7.04849605e-03,
#        -1.12582522e-03,  4.44008633e-02,  5.13456529e-03,  4.15610615e-03,
#         1.07040675e-02,  6.41968008e-03,  8.92904773e-03,  1.33238751e-02,
#        -6.47775363e-03, -8.35650600e-03, -2.24920790e-04,  1.39314840e-02,
#        -6.15584152e-03,  8.00466910e-03,  5.47596114e-03,  1.43046845e-02,
#        -1.79602541e-02,  6.36744779e-03,  4.82484838e-03,  1.09697003e-02,
#        -4.43919271e-04,  6.85688527e-03,  2.84375483e-03,  1.78882945e-03],
#       dtype=float32)

# %%
# zimin과 black_eyed_peas를 내적하는 코드
np.dot(zimin_vector, black_eyed_peas_vector)
# Out:
# 0.50643253

# %%
# zimin 의 queen에 대한 선호도
queen = artist_to_idx['queen']
queen_vector = als_model.item_factors[queen]
np.dot(zimin_vector, queen_vector)
# Out:
# 0.3077224

# %% [markdown]
# ## 13-8. 비슷한 아티스트 찾기 + 유저에게 추천하기

# %% [markdown]
# AlternatingLeastSquares 클래스에 구현되어 있는 similar_items 메서드를 통하여 비슷한 아티스트를 찾습니다. 처음으로는 제가 좋아하는 coldplay로 찾아보겠습니다.

# %%
favorite_artist = 'coldplay'
artist_id = artist_to_idx[favorite_artist]
similar_artist = als_model.similar_items(artist_id, N=15)
similar_artist
# Out:
# [(62, 1.0),
#  (277, 0.9838715),
#  (28, 0.98033243),
#  (5, 0.9752921),
#  (217, 0.97045296),
#  (247, 0.9605731),
#  (490, 0.9569908),
#  (473, 0.954025),
#  (418, 0.9518746),
#  (694, 0.9487184),
#  (1018, 0.9466877),
#  (910, 0.9445164),
#  (782, 0.9410867),
#  (268, 0.9393674),
#  (55, 0.93723893)]

# %%
#artist_to_idx 를 뒤집어, index로부터 artist 이름을 얻는 dict를 생성합니다. 
idx_to_artist = {v:k for k,v in artist_to_idx.items()}
[idx_to_artist[i[0]] for i in similar_artist]
# Out:
# ['coldplay',
#  'muse',
#  'the killers',
#  'red hot chili peppers',
#  'radiohead',
#  'the beatles',
#  'oasis',
#  'placebo',
#  'u2',
#  'foo fighters',
#  'the smashing pumpkins',
#  'nirvana',
#  'the white stripes',
#  'pink floyd',
#  'arctic monkeys']

# %%
def get_similar_artist(artist_name: str):
    artist_id = artist_to_idx[artist_name]
    similar_artist = als_model.similar_items(artist_id)
    similar_artist = [idx_to_artist[i[0]] for i in similar_artist]
    return similar_artist

print("슝=3")
# Out:
# 슝=3

# %%
get_similar_artist('2pac')
# Out:
# ['2pac',
#  'notorious b.i.g.',
#  'dr. dre',
#  'nas',
#  'snoop dogg',
#  'jay-z',
#  'the game',
#  '50 cent',
#  'ice cube',
#  'dmx']

# %%
get_similar_artist('lady gaga')
# Out:
# ['lady gaga',
#  'britney spears',
#  'katy perry',
#  'rihanna',
#  'beyoncé',
#  'the pussycat dolls',
#  'christina aguilera',
#  'justin timberlake',
#  'kelly clarkson',
#  'leona lewis']

# %% [markdown]
# - 유저에게 아티스트 추천하기
# AlternatingLeastSquares 클래스에 구현되어 있는 recommend 메서드를 통하여 제가 좋아할 만한 아티스트를 추천받습니다. filter_already_liked_items 는 유저가 이미 평가한 아이템은 제외하는 Argument입니다.

# %%
user = user_to_idx['zimin']
# recommend에서는 user*item CSR Matrix를 받습니다.
artist_recommended = als_model.recommend(user, csr_data, N=20, filter_already_liked_items=True)
artist_recommended
# Out:
# [(350, 0.45859885),
#  (550, 0.44286054),
#  (274, 0.43588474),
#  (369, 0.43560964),
#  (627, 0.428357),
#  (1800, 0.41630518),
#  (354, 0.40590113),
#  (2249, 0.40164697),
#  (564, 0.398237),
#  (391, 0.39212477),
#  (901, 0.38371074),
#  (355, 0.38169423),
#  (944, 0.37987208),
#  (621, 0.37600046),
#  (5555, 0.36583412),
#  (618, 0.36148536),
#  (5, 0.35421723),
#  (409, 0.35392964),
#  (434, 0.3495996),
#  (28, 0.34888798)]

# %%
[idx_to_artist[i[0]] for i in artist_recommended]
# Out:
# ['rihanna',
#  'britney spears',
#  'michael jackson',
#  'justin timberlake',
#  'maroon 5',
#  'lady gaga',
#  'nelly furtado',
#  'katy perry',
#  'kanye west',
#  'christina aguilera',
#  'pink',
#  'madonna',
#  'avril lavigne',
#  'alicia keys',
#  'timbaland',
#  'the pussycat dolls',
#  'red hot chili peppers',
#  'amy winehouse',
#  'eminem',
#  'the killers']

# %% [markdown]
# rihanna를 추천해 주고 있네요. 모델은 왜 rihanna를 추천해 줬을까요? AlternatingLeastSquares 클래스에 구현된 explain 메서드를 사용하면 제가 기록을 남긴 데이터 중 이 추천에 기여한 정도를 확인할 수 있습니다.

# %%
rihanna = artist_to_idx['rihanna']
explain = als_model.explain(user, csr_data, itemid=rihanna)

# %%
[(idx_to_artist[i[0]], i[1]) for i in explain[1]]
# Out:
# [('beyoncé', 0.21852383445575171),
#  ('black eyed peas', 0.14660473281285974),
#  ('jason mraz', 0.06728769369799792),
#  ('coldplay', 0.029331495610468238),
#  ('maroon5', -0.00024456002888732456)]
